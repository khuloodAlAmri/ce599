# %% [markdown]
# ### Open Flights Data Wrangling
#
# To practice, you are going to wrangle data from OpenFlights.  You can read about it here:
#
# http://openflights.org/data.html
#
# This includes three main files, one for each airport, one for each airline, and one for each route.  They can be merged or joined with the appropriate fields.  I have modified the files slightly to include a header row in the .dat files, which makes it a bit easier for you.
#
# You are required to work through the problems below.  This may take some time.  Be persistent, and ask questions or seek help as needed.

# %%
import pandas as pd
import numpy as np

# %%
# These files use \N as a missing value indicator.  When reading the CSVs, we will tell
# it to use that value as missing or NA.  The double backslash is required because
# otherwise it will interpret \N as a carriage return. 

# Read in the airports data.
airports = pd.read_csv("data/airports.dat", header=None, na_values='\\N')
airports.columns = ["id", "name", "city", "country", "iata", "icao", "latitude", "longitude", "altitude","timezone", "dst", "tz", "type", "source"]

# Read in the airlines data.
airlines = pd.read_csv("data/airlines.dat", header=None, na_values='\\N')
airlines.columns = ["id", "name", "alias", "iata", "icao", "callsign", "country", "active"]

# Read in the routes data.
routes = pd.read_csv("data/routes.dat", header=None, na_values='\\N')
routes.columns = ["airline", "airline_id", "source", "source_id", "dest", "dest_id", "codeshare", "stops", "equipment"]

# %% [markdown]
# 1) Start by seeing what's in the data.  What columns are there?  What data types are the columns?
#
# Remember, 'object' means it is a string, while the numerical values can be floats or ints.  Sometimes you will have problems if it reads numeric data in as strings.  If that happens, you can use the function .astype() to convert it.  Look it up in the pandas API to get more details

# %%
import pandas as pd
import numpy as np

# %%
airlines = pd.read_csv("data/airlines.dat", header=None, na_values='\\N')
airlines.columns = ["id", "name", "alias", "iata", "icao", "callsign", "country", "active"]
airlines
# Out:
#          id                                          name  \
# 0        -1                                       Unknown
# 1         1                                Private flight
# 2         2                                   135 Airways
# 3         3                                 1Time Airline
# 4         4  2 Sqn No 1 Elementary Flying Training School
# 5         5                               213 Flight Unit
# 6         6                 223 Flight Unit State Airline
# 7         7                             224th Flight Unit
# 8         8                                   247 Jet Ltd
# 9         9                                   3D Aviation
# 10       10                                   40-Mile Air
# 11       11                                        4D Air
# 12       12                        611897 Alberta Limited
# 13       13                              Ansett Australia
# 14       14                          Abacus International
# 15       15                               Abelag Aviation
# 16       16                                Army Air Corps
# 17       17                     Aero Aviation Centre Ltd.
# 18       18     Aero Servicios Ejecutivos Internacionales
# 19       19                                   Aero Biniza
# 20       20                                 Aero Albatros
# 21       21                                    Aigle Azur
# 22       22                                Aloha Airlines
# 23       23                             Alaska Island Air
# 24       24                             American Airlines
# 25       25               Aviation Management Corporation
# 26       26                       Atlantis Airlines (USA)
# 27       27                            Aerovista Airlines
# 28       28                               Asiana Airlines
# 29       29                               Askari Aviation
# ...     ...                                           ...
# 6132  20827                                    Fly France
# 6133  20875                                 Jota Aviation
# 6134  20881                                    Europe Jet
# 6135  20923                                        COBALT
# 6136  20931                      Southern Airways Express
# 6137  20961       Deutsche Luftverkehrsgesellschaft (DLT)
# 6138  20962                                   Orenburzhie
# 6139  20963                            Atlantic Air Cargo
# 6140  20976                          World Scale Airlines
# 6141  20978                                All America US
# 6142  20986   University of Birmingham Air Squadron (RAF)
# 6143  20991                                Choice Airways
# 6144  20994                                Aruba Airlines
# 6145  20995                                     BudgetAir
# 6146  20996                               Dynamic Airways
# 6147  21012                                       Fly One
# 6148  21021                                       Nordica
# 6149  21036                              Tez Jet Airlines
# 6150  21043                                      Kush Air
# 6151  21056                                         Dummy
# 6152  21124                                        ViaAir
# 6153  21131                              All America BOPY
# 6154  21179                              Thai Vietjet Air
# 6155  21181                              Air Andaman (2Y)
# 6156  21240                     TDA Toa Domestic Airlines
# 6157  21248                                   GX Airlines
# 6158  21251                        Lynx Aviation (L3/SSX)
# 6159  21268                               Jetgo Australia
# 6160  21270                                  Air Carnival
# 6161  21317                                 Svyaz Rossiya
#
#                       alias iata icao         callsign               country  \
# 0                       NaN    -  NaN              NaN                   NaN
# 1                       NaN    -  NaN              NaN                   NaN
# 2                       NaN  NaN  GNL          GENERAL         United States
# 3                       NaN   1T  RNX          NEXTIME          South Africa
# 4                       NaN  NaN  WYT              NaN        United Kingdom
# 5                       NaN  NaN  TFU              NaN                Russia
# 6                       NaN  NaN  CHD   CHKALOVSK-AVIA                Russia
# 7                       NaN  NaN  TTF       CARGO UNIT                Russia
# 8                       NaN  NaN  TWF     CLOUD RUNNER        United Kingdom
# 9                       NaN  NaN  SEC          SECUREX         United States
# 10                      NaN   Q5  MLA         MILE-AIR         United States
# 11                      NaN  NaN  QRT          QUARTET              Thailand
# 12                      NaN  NaN  THD            DONUT                Canada
# 13                      NaN   AN  AAA           ANSETT             Australia
# 14                      NaN   1B  NaN              NaN             Singapore
# 15                      NaN   W9  AAB              ABG               Belgium
# 16                      NaN  NaN  AAC          ARMYAIR        United Kingdom
# 17                      NaN  NaN  AAD          SUNRISE                Canada
# 18                      NaN  NaN  SII           ASEISA                Mexico
# 19                      NaN  NaN  BZS           BINIZA                Mexico
# 20                      NaN  NaN  ABM  ALBATROS ESPANA                 Spain
# 21                      NaN   ZI  AAF       AIGLE AZUR                France
# 22                      NaN   AQ  AAH            ALOHA         United States
# 23                      NaN  NaN  AAK    ALASKA ISLAND         United States
# 24                      NaN   AA  AAL         AMERICAN         United States
# 25                      NaN  NaN  AAM          AM CORP         United States
# 26                      NaN  NaN  AAO     ATLANTIS AIR         United States
# 27                      NaN  NaN  AAP  AEROVISTA GROUP  United Arab Emirates
# 28                      NaN   OZ  AAR           ASIANA     Republic of Korea
# 29                      NaN   4K  AAS           AL-AAS              Pakistan
# ...                     ...  ...  ...              ...                   ...
# 6132             Fly France   FF  FRF              NaN                France
# 6133                    NaN  NaN  ENZ             ENZO        United Kingdom
# 6134             Europe Jet   EX  EU9              NaN                France
# 6135                 COBALT  NaN  FCB           COBALT                Cyprus
# 6136        Sun Air Express  NaN  LTD       LIGHTSPEED         United States
# 6137                    NaN   DW  DWD              NaN               Germany
# 6138                    NaN  NaN  ORG              NaN                Russia
# 6139                    NaN   K3  NaN              NaN         United States
# 6140            World Scale   W3  WSS              NaN         United States
# 6141         All America US   AG  SSA              NaN         United States
# 6142               8AEF RAF  NaN  UAY              UAY        United Kingdom
# 6143                    NaN  NaN  CSX              NaN         United States
# 6144                    NaN  NaN  ARU              NaN                 Aruba
# 6145              BudgetAir   1K  BG1              NaN               Germany
# 6146                    NaN  NaN  DYA              NaN         United States
# 6147                Fly One   F5  FI5              NaN               Moldova
# 6148                    NaN   EE  NaN            REVAL               Estonia
# 6149                    NaN  NaN  TEZ              NaN            Kyrgyzstan
# 6150                    NaN  NaN  KUH              NaN           South Sudan
# 6151                    NaN   0E  NaN              NaN                France
# 6152  Charter Air Transport  NaN  SRY         Stingray         United States
# 6153       All America BOPY   0P  PYB             BOPY              Paraguay
# 6154                    NaN  NaN  TVJ     THAIVIET JET              Thailand
# 6155                    NaN   2Y  AOW      AIR ANDAMAN              Thailand
# 6156                    TDA  NaN  TDA        Toa Domes                 Japan
# 6157                    NaN  NaN  CBG            SPRAY                 China
# 6158                    NaN  NaN  SSX           Shasta         United States
# 6159                    NaN   JG  NaN              NaN             Australia
# 6160                    NaN   2S  NaN              NaN                 India
# 6161      Russian Commuter    7R  SJM  RussianConnecty                Russia
#
#      active
# 0         Y
# 1         Y
# 2         N
# 3         Y
# 4         N
# 5         N
# 6         N
# 7         N
# 8         N
# 9         N
# 10        Y
# 11        N
# 12        N
# 13        Y
# 14        Y
# 15        N
# 16        N
# 17        N
# 18        N
# 19        N
# 20        N
# 21        Y
# 22        Y
# 23        N
# 24        Y
# 25        N
# 26        N
# 27        N
# 28        Y
# 29        Y
# ...     ...
# 6132      Y
# 6133      Y
# 6134      Y
# 6135      Y
# 6136      Y
# 6137      N
# 6138      Y
# 6139      N
# 6140      Y
# 6141      Y
# 6142      Y
# 6143      Y
# 6144      Y
# 6145      Y
# 6146      Y
# 6147      Y
# 6148      Y
# 6149      Y
# 6150      Y
# 6151      N
# 6152      Y
# 6153      Y
# 6154      Y
# 6155      N
# 6156      N
# 6157      Y
# 6158      N
# 6159      Y
# 6160      Y
# 6161      Y
#
# [6162 rows x 8 columns]

# %% [markdown]
# 2) Select just the routes that go to or from Lexington Bluegrass Airport, and store them in their own dataframe.
#
# The airport code is LEX.  You should have a much smaller dataframe.  How many inbound routes and how many outbound routes are there?

# %%
lex_routes = routes[(routes['source']=="LEX")]
lex_routes = pd.merge(lex_routes, airports, left_on='source_id', right_on='id', how='left')

# %%
lex_routes = pd.merge(lex_routes, airports, 
                      left_on='dest_id', 
                      right_on='id', 
                      how='left', 
                      suffixes=['_source','_dest'])
lex_routes
# Out:
#    airline  airline_id source_x  source_id dest  dest_id codeshare  stops  \
# 0       9E      3976.0      LEX     4017.0  ATL   3682.0       NaN      0
# 1       AA        24.0      LEX     4017.0  CLT   3876.0         Y      0
# 2       AA        24.0      LEX     4017.0  DFW   3670.0         Y      0
# 3       AA        24.0      LEX     4017.0  ORD   3830.0         Y      0
# 4       AF       137.0      LEX     4017.0  ATL   3682.0         Y      0
# 5       DL      2009.0      LEX     4017.0  ATL   3682.0       NaN      0
# 6       DL      2009.0      LEX     4017.0  DCA   3520.0         Y      0
# 7       DL      2009.0      LEX     4017.0  DTW   3645.0         Y      0
# 8       DL      2009.0      LEX     4017.0  LGA   3697.0       NaN      0
# 9       DL      2009.0      LEX     4017.0  MSP   3858.0         Y      0
# 10      G4        35.0      LEX     4017.0  FLL   3533.0       NaN      0
# 11      G4        35.0      LEX     4017.0  PGD   7056.0       NaN      0
# 12      G4        35.0      LEX     4017.0  PIE   3617.0       NaN      0
# 13      G4        35.0      LEX     4017.0  SFB   4167.0       NaN      0
# 14      KL      3090.0      LEX     4017.0  ATL   3682.0         Y      0
# 15      UA      5209.0      LEX     4017.0  IAH   3550.0         Y      0
# 16      UA      5209.0      LEX     4017.0  ORD   3830.0         Y      0
# 17      US      5265.0      LEX     4017.0  CLT   3876.0       NaN      0
# 18      US      5265.0      LEX     4017.0  DFW   3670.0       NaN      0
# 19      US      5265.0      LEX     4017.0  ORD   3830.0         Y      0
#
#       equipment  id_source     ...      iata_dest icao_dest latitude_dest  \
# 0           CRJ       4017     ...            ATL      KATL     33.636700
# 1       CR7 CRJ       4017     ...            CLT      KCLT     35.214001
# 2       ERD ER4       4017     ...            DFW      KDFW     32.896801
# 3       ERD ER4       4017     ...            ORD      KORD     41.978600
# 4       CRJ CR9       4017     ...            ATL      KATL     33.636700
# 5       M88 717       4017     ...            ATL      KATL     33.636700
# 6           CRJ       4017     ...            DCA      KDCA     38.852100
# 7   CR7 CRJ CR9       4017     ...            DTW      KDTW     42.212399
# 8           ERJ       4017     ...            LGA      KLGA     40.777199
# 9           CRJ       4017     ...            MSP      KMSP     44.882000
# 10          M80       4017     ...            FLL      KFLL     26.072599
# 11          M80       4017     ...            PGD      KPGD     26.920200
# 12          320       4017     ...            PIE      KPIE     27.910200
# 13      M80 320       4017     ...            SFB      KSFB     28.777599
# 14      CR9 CRJ       4017     ...            ATL      KATL     33.636700
# 15          ERJ       4017     ...            IAH      KIAH     29.984400
# 16      ERJ CRJ       4017     ...            ORD      KORD     41.978600
# 17          CR7       4017     ...            CLT      KCLT     35.214001
# 18          ERD       4017     ...            DFW      KDFW     32.896801
# 19      ERD ER4       4017     ...            ORD      KORD     41.978600
#
#    longitude_dest altitude_dest  timezone_dest  dst_dest           tz_dest  \
# 0      -84.428101          1026           -5.0         A  America/New_York
# 1      -80.943100           748           -5.0         A  America/New_York
# 2      -97.038002           607           -6.0         A   America/Chicago
# 3      -87.904800           672           -6.0         A   America/Chicago
# 4      -84.428101          1026           -5.0         A  America/New_York
# 5      -84.428101          1026           -5.0         A  America/New_York
# 6      -77.037697            15           -5.0         A  America/New_York
# 7      -83.353401           645           -5.0         A  America/New_York
# 8      -73.872597            21           -5.0         A  America/New_York
# 9      -93.221802           841           -6.0         A   America/Chicago
# 10     -80.152702             9           -5.0         A  America/New_York
# 11     -81.990501            26           -5.0         A  America/New_York
# 12     -82.687401            11           -5.0         A  America/New_York
# 13     -81.237503            55           -5.0         A  America/New_York
# 14     -84.428101          1026           -5.0         A  America/New_York
# 15     -95.341400            97           -6.0         A   America/Chicago
# 16     -87.904800           672           -6.0         A   America/Chicago
# 17     -80.943100           748           -5.0         A  America/New_York
# 18     -97.038002           607           -6.0         A   America/Chicago
# 19     -87.904800           672           -6.0         A   America/Chicago
#
#     type_dest       source
# 0     airport  OurAirports
# 1     airport  OurAirports
# 2     airport  OurAirports
# 3     airport  OurAirports
# 4     airport  OurAirports
# 5     airport  OurAirports
# 6     airport  OurAirports
# 7     airport  OurAirports
# 8     airport  OurAirports
# 9     airport  OurAirports
# 10    airport  OurAirports
# 11    airport  OurAirports
# 12    airport  OurAirports
# 13    airport  OurAirports
# 14    airport  OurAirports
# 15    airport  OurAirports
# 16    airport  OurAirports
# 17    airport  OurAirports
# 18    airport  OurAirports
# 19    airport  OurAirports
#
# [20 rows x 37 columns]

# %% [markdown]
# 3) Now let's look at which airlines operate in and out of Lexington.  To do this, you need to merge the airline dataframe to the route dataframe.
#
# How many routes does each airline have?  The value_counts() method may be useful for answering this question.

# %%
airline_LEX= pd.merge(lex_routes, airlines, left_on='airline_id',right_on='id')
airline_LEX
# Out:
#    airline  airline_id source_x  source_id dest  dest_id codeshare  stops  \
# 0       9E      3976.0      LEX     4017.0  ATL   3682.0       NaN      0
# 1       AA        24.0      LEX     4017.0  CLT   3876.0         Y      0
# 2       AA        24.0      LEX     4017.0  DFW   3670.0         Y      0
# 3       AA        24.0      LEX     4017.0  ORD   3830.0         Y      0
# 4       AF       137.0      LEX     4017.0  ATL   3682.0         Y      0
# 5       DL      2009.0      LEX     4017.0  ATL   3682.0       NaN      0
# 6       DL      2009.0      LEX     4017.0  DCA   3520.0         Y      0
# 7       DL      2009.0      LEX     4017.0  DTW   3645.0         Y      0
# 8       DL      2009.0      LEX     4017.0  LGA   3697.0       NaN      0
# 9       DL      2009.0      LEX     4017.0  MSP   3858.0         Y      0
# 10      G4        35.0      LEX     4017.0  FLL   3533.0       NaN      0
# 11      G4        35.0      LEX     4017.0  PGD   7056.0       NaN      0
# 12      G4        35.0      LEX     4017.0  PIE   3617.0       NaN      0
# 13      G4        35.0      LEX     4017.0  SFB   4167.0       NaN      0
# 14      KL      3090.0      LEX     4017.0  ATL   3682.0         Y      0
# 15      UA      5209.0      LEX     4017.0  IAH   3550.0         Y      0
# 16      UA      5209.0      LEX     4017.0  ORD   3830.0         Y      0
# 17      US      5265.0      LEX     4017.0  CLT   3876.0       NaN      0
# 18      US      5265.0      LEX     4017.0  DFW   3670.0       NaN      0
# 19      US      5265.0      LEX     4017.0  ORD   3830.0         Y      0
#
#       equipment  id_source  ...   type_dest       source    id  \
# 0           CRJ       4017  ...     airport  OurAirports  3976
# 1       CR7 CRJ       4017  ...     airport  OurAirports    24
# 2       ERD ER4       4017  ...     airport  OurAirports    24
# 3       ERD ER4       4017  ...     airport  OurAirports    24
# 4       CRJ CR9       4017  ...     airport  OurAirports   137
# 5       M88 717       4017  ...     airport  OurAirports  2009
# 6           CRJ       4017  ...     airport  OurAirports  2009
# 7   CR7 CRJ CR9       4017  ...     airport  OurAirports  2009
# 8           ERJ       4017  ...     airport  OurAirports  2009
# 9           CRJ       4017  ...     airport  OurAirports  2009
# 10          M80       4017  ...     airport  OurAirports    35
# 11          M80       4017  ...     airport  OurAirports    35
# 12          320       4017  ...     airport  OurAirports    35
# 13      M80 320       4017  ...     airport  OurAirports    35
# 14      CR9 CRJ       4017  ...     airport  OurAirports  3090
# 15          ERJ       4017  ...     airport  OurAirports  5209
# 16      ERJ CRJ       4017  ...     airport  OurAirports  5209
# 17          CR7       4017  ...     airport  OurAirports  5265
# 18          ERD       4017  ...     airport  OurAirports  5265
# 19      ERD ER4       4017  ...     airport  OurAirports  5265
#
#                         name alias  iata  icao   callsign        country  \
# 0          Pinnacle Airlines   NaN    9E   FLG   FLAGSHIP  United States
# 1          American Airlines   NaN    AA   AAL   AMERICAN  United States
# 2          American Airlines   NaN    AA   AAL   AMERICAN  United States
# 3          American Airlines   NaN    AA   AAL   AMERICAN  United States
# 4                 Air France   NaN    AF   AFR   AIRFRANS         France
# 5            Delta Air Lines   NaN    DL   DAL      DELTA  United States
# 6            Delta Air Lines   NaN    DL   DAL      DELTA  United States
# 7            Delta Air Lines   NaN    DL   DAL      DELTA  United States
# 8            Delta Air Lines   NaN    DL   DAL      DELTA  United States
# 9            Delta Air Lines   NaN    DL   DAL      DELTA  United States
# 10             Allegiant Air   NaN    G4   AAY  ALLEGIANT  United States
# 11             Allegiant Air   NaN    G4   AAY  ALLEGIANT  United States
# 12             Allegiant Air   NaN    G4   AAY  ALLEGIANT  United States
# 13             Allegiant Air   NaN    G4   AAY  ALLEGIANT  United States
# 14  KLM Royal Dutch Airlines   NaN    KL   KLM        KLM    Netherlands
# 15           United Airlines   NaN    UA   UAL     UNITED  United States
# 16           United Airlines   NaN    UA   UAL     UNITED  United States
# 17                US Airways   NaN    US   USA    U S AIR  United States
# 18                US Airways   NaN    US   USA    U S AIR  United States
# 19                US Airways   NaN    US   USA    U S AIR  United States
#
#    active
# 0       Y
# 1       Y
# 2       Y
# 3       Y
# 4       Y
# 5       Y
# 6       Y
# 7       Y
# 8       Y
# 9       Y
# 10      Y
# 11      Y
# 12      Y
# 13      Y
# 14      Y
# 15      Y
# 16      Y
# 17      Y
# 18      Y
# 19      Y
#
# [20 rows x 45 columns]

# %% [markdown]
# 4) It looks like there are some international airlines with Lexington routes.  To look at how many routes they have, create a new column in your dataframe called 'International', which is set to Y for an overseas airline and N for a domestic airline.  Calculate the percent of routes with an overseas airline.

# %%
is_International= []
for domestic_static in airline_LEX['country']=='United states':
    if domestic_static:
         is_International.append('N')
    else:
        is_International.append('Y')
In_airline_LEX= airline_LEX.assign(Intern=is_International)
In_airline_LEX
# Out:
#    airline  airline_id source_x  source_id dest  dest_id codeshare  stops  \
# 0       9E      3976.0      LEX     4017.0  ATL   3682.0       NaN      0
# 1       AA        24.0      LEX     4017.0  CLT   3876.0         Y      0
# 2       AA        24.0      LEX     4017.0  DFW   3670.0         Y      0
# 3       AA        24.0      LEX     4017.0  ORD   3830.0         Y      0
# 4       AF       137.0      LEX     4017.0  ATL   3682.0         Y      0
# 5       DL      2009.0      LEX     4017.0  ATL   3682.0       NaN      0
# 6       DL      2009.0      LEX     4017.0  DCA   3520.0         Y      0
# 7       DL      2009.0      LEX     4017.0  DTW   3645.0         Y      0
# 8       DL      2009.0      LEX     4017.0  LGA   3697.0       NaN      0
# 9       DL      2009.0      LEX     4017.0  MSP   3858.0         Y      0
# 10      G4        35.0      LEX     4017.0  FLL   3533.0       NaN      0
# 11      G4        35.0      LEX     4017.0  PGD   7056.0       NaN      0
# 12      G4        35.0      LEX     4017.0  PIE   3617.0       NaN      0
# 13      G4        35.0      LEX     4017.0  SFB   4167.0       NaN      0
# 14      KL      3090.0      LEX     4017.0  ATL   3682.0         Y      0
# 15      UA      5209.0      LEX     4017.0  IAH   3550.0         Y      0
# 16      UA      5209.0      LEX     4017.0  ORD   3830.0         Y      0
# 17      US      5265.0      LEX     4017.0  CLT   3876.0       NaN      0
# 18      US      5265.0      LEX     4017.0  DFW   3670.0       NaN      0
# 19      US      5265.0      LEX     4017.0  ORD   3830.0         Y      0
#
#       equipment  id_source  ...      id                      name alias iata  \
# 0           CRJ       4017  ...    3976         Pinnacle Airlines   NaN   9E
# 1       CR7 CRJ       4017  ...      24         American Airlines   NaN   AA
# 2       ERD ER4       4017  ...      24         American Airlines   NaN   AA
# 3       ERD ER4       4017  ...      24         American Airlines   NaN   AA
# 4       CRJ CR9       4017  ...     137                Air France   NaN   AF
# 5       M88 717       4017  ...    2009           Delta Air Lines   NaN   DL
# 6           CRJ       4017  ...    2009           Delta Air Lines   NaN   DL
# 7   CR7 CRJ CR9       4017  ...    2009           Delta Air Lines   NaN   DL
# 8           ERJ       4017  ...    2009           Delta Air Lines   NaN   DL
# 9           CRJ       4017  ...    2009           Delta Air Lines   NaN   DL
# 10          M80       4017  ...      35             Allegiant Air   NaN   G4
# 11          M80       4017  ...      35             Allegiant Air   NaN   G4
# 12          320       4017  ...      35             Allegiant Air   NaN   G4
# 13      M80 320       4017  ...      35             Allegiant Air   NaN   G4
# 14      CR9 CRJ       4017  ...    3090  KLM Royal Dutch Airlines   NaN   KL
# 15          ERJ       4017  ...    5209           United Airlines   NaN   UA
# 16      ERJ CRJ       4017  ...    5209           United Airlines   NaN   UA
# 17          CR7       4017  ...    5265                US Airways   NaN   US
# 18          ERD       4017  ...    5265                US Airways   NaN   US
# 19      ERD ER4       4017  ...    5265                US Airways   NaN   US
#
#    icao   callsign        country  active  International Intern
# 0   FLG   FLAGSHIP  United States       Y          False      Y
# 1   AAL   AMERICAN  United States       Y          False      Y
# 2   AAL   AMERICAN  United States       Y          False      Y
# 3   AAL   AMERICAN  United States       Y          False      Y
# 4   AFR   AIRFRANS         France       Y          False      Y
# 5   DAL      DELTA  United States       Y          False      Y
# 6   DAL      DELTA  United States       Y          False      Y
# 7   DAL      DELTA  United States       Y          False      Y
# 8   DAL      DELTA  United States       Y          False      Y
# 9   DAL      DELTA  United States       Y          False      Y
# 10  AAY  ALLEGIANT  United States       Y          False      Y
# 11  AAY  ALLEGIANT  United States       Y          False      Y
# 12  AAY  ALLEGIANT  United States       Y          False      Y
# 13  AAY  ALLEGIANT  United States       Y          False      Y
# 14  KLM        KLM    Netherlands       Y          False      Y
# 15  UAL     UNITED  United States       Y          False      Y
# 16  UAL     UNITED  United States       Y          False      Y
# 17  USA    U S AIR  United States       Y          False      Y
# 18  USA    U S AIR  United States       Y          False      Y
# 19  USA    U S AIR  United States       Y          False      Y
#
# [20 rows x 47 columns]

# %% [markdown]
# 5) Actually, it looks like a bunch of these routes are codeshares.  That means they are marketed by this airline, but operated by a different airline.  See the note in the data documentation on openflights.org/data.  The implication of this is that there are duplicates.
#
# Can you figure out which ones are duplicates?  Can you then create a dataframe with only the unique routes?  How many unique inbound and outbound routes are there?
#
# Remember, someone has to operate the flight, so if all the routes to/from a particular airport are listed as codeshares, then something is funny...
#
# It is also possible that more than one airline actually operates a route between the same two airports. (Having this sort of competition generally means that you will get better fares as a traveler.)  It may not be obvious what is actually in the data set, so dig or do external research as needed.

# %%
lex_routes = lex_routes.drop(['source_y','source'], axis=1)
lex_routes = lex_routes.rename(columns={'source_x': 'source'})

# %%
lex_routes = lex_routes.drop_duplicates(subset=['source', 'dest'])
lex_routes
# Out:
#    airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 0       9E      3976.0    LEX     4017.0  ATL   3682.0       NaN      0
# 1       AA        24.0    LEX     4017.0  CLT   3876.0         Y      0
# 2       AA        24.0    LEX     4017.0  DFW   3670.0         Y      0
# 3       AA        24.0    LEX     4017.0  ORD   3830.0         Y      0
# 6       DL      2009.0    LEX     4017.0  DCA   3520.0         Y      0
# 7       DL      2009.0    LEX     4017.0  DTW   3645.0         Y      0
# 8       DL      2009.0    LEX     4017.0  LGA   3697.0       NaN      0
# 9       DL      2009.0    LEX     4017.0  MSP   3858.0         Y      0
# 10      G4        35.0    LEX     4017.0  FLL   3533.0       NaN      0
# 11      G4        35.0    LEX     4017.0  PGD   7056.0       NaN      0
# 12      G4        35.0    LEX     4017.0  PIE   3617.0       NaN      0
# 13      G4        35.0    LEX     4017.0  SFB   4167.0       NaN      0
# 15      UA      5209.0    LEX     4017.0  IAH   3550.0         Y      0
#
#       equipment  id_source    ...      country_dest iata_dest icao_dest  \
# 0           CRJ       4017    ...     United States       ATL      KATL
# 1       CR7 CRJ       4017    ...     United States       CLT      KCLT
# 2       ERD ER4       4017    ...     United States       DFW      KDFW
# 3       ERD ER4       4017    ...     United States       ORD      KORD
# 6           CRJ       4017    ...     United States       DCA      KDCA
# 7   CR7 CRJ CR9       4017    ...     United States       DTW      KDTW
# 8           ERJ       4017    ...     United States       LGA      KLGA
# 9           CRJ       4017    ...     United States       MSP      KMSP
# 10          M80       4017    ...     United States       FLL      KFLL
# 11          M80       4017    ...     United States       PGD      KPGD
# 12          320       4017    ...     United States       PIE      KPIE
# 13      M80 320       4017    ...     United States       SFB      KSFB
# 15          ERJ       4017    ...     United States       IAH      KIAH
#
#    latitude_dest longitude_dest  altitude_dest  timezone_dest  dst_dest  \
# 0      33.636700     -84.428101           1026           -5.0         A
# 1      35.214001     -80.943100            748           -5.0         A
# 2      32.896801     -97.038002            607           -6.0         A
# 3      41.978600     -87.904800            672           -6.0         A
# 6      38.852100     -77.037697             15           -5.0         A
# 7      42.212399     -83.353401            645           -5.0         A
# 8      40.777199     -73.872597             21           -5.0         A
# 9      44.882000     -93.221802            841           -6.0         A
# 10     26.072599     -80.152702              9           -5.0         A
# 11     26.920200     -81.990501             26           -5.0         A
# 12     27.910200     -82.687401             11           -5.0         A
# 13     28.777599     -81.237503             55           -5.0         A
# 15     29.984400     -95.341400             97           -6.0         A
#
#              tz_dest type_dest
# 0   America/New_York   airport
# 1   America/New_York   airport
# 2    America/Chicago   airport
# 3    America/Chicago   airport
# 6   America/New_York   airport
# 7   America/New_York   airport
# 8   America/New_York   airport
# 9    America/Chicago   airport
# 10  America/New_York   airport
# 11  America/New_York   airport
# 12  America/New_York   airport
# 13  America/New_York   airport
# 15   America/Chicago   airport
#
# [13 rows x 35 columns]

# %%
In_airline_LEX_unique= airline_LEX[airline_LEX['codeshare']!='Y']
len(In_airline_LEX_unique)
In_airline_LEX_unique
# Out:
#    airline  airline_id source_x  source_id dest  dest_id codeshare  stops  \
# 0       9E      3976.0      LEX     4017.0  ATL   3682.0       NaN      0
# 5       DL      2009.0      LEX     4017.0  ATL   3682.0       NaN      0
# 8       DL      2009.0      LEX     4017.0  LGA   3697.0       NaN      0
# 10      G4        35.0      LEX     4017.0  FLL   3533.0       NaN      0
# 11      G4        35.0      LEX     4017.0  PGD   7056.0       NaN      0
# 12      G4        35.0      LEX     4017.0  PIE   3617.0       NaN      0
# 13      G4        35.0      LEX     4017.0  SFB   4167.0       NaN      0
# 17      US      5265.0      LEX     4017.0  CLT   3876.0       NaN      0
# 18      US      5265.0      LEX     4017.0  DFW   3670.0       NaN      0
#
#    equipment  id_source      ...            source    id               name  \
# 0        CRJ       4017      ...       OurAirports  3976  Pinnacle Airlines
# 5    M88 717       4017      ...       OurAirports  2009    Delta Air Lines
# 8        ERJ       4017      ...       OurAirports  2009    Delta Air Lines
# 10       M80       4017      ...       OurAirports    35      Allegiant Air
# 11       M80       4017      ...       OurAirports    35      Allegiant Air
# 12       320       4017      ...       OurAirports    35      Allegiant Air
# 13   M80 320       4017      ...       OurAirports    35      Allegiant Air
# 17       CR7       4017      ...       OurAirports  5265         US Airways
# 18       ERD       4017      ...       OurAirports  5265         US Airways
#
#    alias iata  icao   callsign        country  active International
# 0    NaN   9E   FLG   FLAGSHIP  United States       Y         False
# 5    NaN   DL   DAL      DELTA  United States       Y         False
# 8    NaN   DL   DAL      DELTA  United States       Y         False
# 10   NaN   G4   AAY  ALLEGIANT  United States       Y         False
# 11   NaN   G4   AAY  ALLEGIANT  United States       Y         False
# 12   NaN   G4   AAY  ALLEGIANT  United States       Y         False
# 13   NaN   G4   AAY  ALLEGIANT  United States       Y         False
# 17   NaN   US   USA    U S AIR  United States       Y         False
# 18   NaN   US   USA    U S AIR  United States       Y         False
#
# [9 rows x 46 columns]
